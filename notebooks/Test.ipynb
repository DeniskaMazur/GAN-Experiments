# %%
import sys
sys.path.append("../")

# %%
from lib.zoo.remaster_resgen import Resgen

# %%
gen = Resgen([None, 24, 100])
# Out:
# here
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5d00261bb5cc> in <module>()
# ----> 1 gen = Resgen([None, 24, 100])
#
# /home/deniska/Projects/gan-experiments/lib/zoo/remaster_resgen.pyc in __init__(self, inp_dims, n_base_filter, n_residual, nonlinearity, norm_func)
#      29         self.norm_func = norm_func
#      30
# ---> 31         super(Resgen, self).__init__(inp_dims)
#      32
#      33     def _build_net(self):
#
# /home/deniska/Projects/gan-experiments/lib/zoo/base_generator.py in __init__(self, inp_dims)
#      25         # generation function
#      26         print "here"
# ---> 27         self.generate = theano.function([self.input_var], self.output_var)
#      28
#      29     def _build_net(self):
#
# ...
